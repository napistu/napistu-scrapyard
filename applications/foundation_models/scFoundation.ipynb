# %%
import logging
import os

import pandas as pd

from scFoundation import process_scfoundation, load_gene_annotations, extract_weights, extract_metadata, GENE_LIST_URL, FM_DEFS, ONTOLOGIES
# reuse annotations the annotations that are bundled with AIDOCell since they are the same
# and the AIDOCell annotations include Ensembl gene ids
from AIDOCell import load_gene_annotations


logger = logging.getLogger(__name__)

DATA_DIR = "data"
OUTPUT_DIR = "output"

# %%
model = process_scfoundation(output_dir=OUTPUT_DIR)
